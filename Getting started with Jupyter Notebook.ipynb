# %%
import pandas as pd
df = read_csv('file.csv')
print(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d3d32a3beca1> in <module>
# ----> 1 import pandas as pd
#       2 df = read_csv('file.csv')
#       3 print(df)
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import sys; print (sys.path)
# Out:
# ['/usr/lib/python36.zip', '/usr/lib/python3.6', '/usr/lib/python3.6/lib-dynload', '', '/home/kishor/.local/lib/python3.6/site-packages', '/usr/local/lib/python3.6/dist-packages', '/usr/lib/python3/dist-packages', '/home/kishor/.local/lib/python3.6/site-packages/IPython/extensions', '/home/kishor/.ipython']

# %%
# Install a conda package in the current Jupyter kernel
import sys
# !conda install --yes --prefix {sys.prefix} numpy
# Out:
# /bin/bash: conda: command not found

# %%
import sys
# !{sys.executable} -m pip install numpy

# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install numpy
# Out:
# Collecting numpy
#   Cache entry deserialization failed, entry ignored
#   Using cached https://files.pythonhosted.org/packages/22/e7/4b2bdddb99f5f631d8c1de259897c2b7d65dcfcc1e0a6fd17a7f62923500/numpy-1.19.1-cp36-cp36m-manylinux1_x86_64.whl
# Installing collected packages: numpy
# Successfully installed numpy-1.19.1

# %%
import numpy as np

# %%
# import pre-built image from minimal notebook 
    FROM jupyter/minimal-notebook
    # Install required libraries
    RUN pip install preprocess1
# Out:
#   File "<ipython-input-3-922d342df754>", line 2
#     FROM jupyter/minimal-notebook
#     ^
# IndentationError: unexpected indent

# %%
# import pre-built image from minimal notebook 
    from jupyter/minimal-notebook
    # Install required libraries
    RUN pip install preprocess1
# Out:
#   File "<ipython-input-4-e38fd7bb318f>", line 2
#     from jupyter/minimal-notebook
#     ^
# IndentationError: unexpected indent

# %%
# import pre-built image from minimal notebook 
FROM jupyter/minimal-notebook
    # Install required libraries
RUN pip install preprocess1
# Out:
#   File "<ipython-input-5-ee5f10cbb104>", line 2
#     FROM jupyter/minimal-notebook
#                ^
# SyntaxError: invalid syntax

# %%
cls
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4b94d9d35cf3> in <module>
# ----> 1 cls
#
# NameError: name 'cls' is not defined

# %%
import matplotlib.pyplot as plt

# x axis values
x = [1, 2, 3]
# corresponding y axis values
y = [2, 4, 1]

# plotting the points
plt.plot(x, y)
# function to show the plot
plt.show()

# %%
import pandas as pd
df = pd.read_csv ('/home/kishor/PycharmProjects/Getting_Started_with_ML/diabt.csv')
print (df.describe())

import matplotlib.pyplot as plt
import seaborn as sns
fig = sns.pairplot(df, hue= 'Outcome', kind = 'reg')
plt.show()
fig.savefig('pairplot_diabetics', bbox_inches = 'tight')
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
save.
